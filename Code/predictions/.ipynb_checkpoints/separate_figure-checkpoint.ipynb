# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Load the data from the Excel file
file_path = 'new_test_predictions_with_id.xlsx'
data = pd.read_excel(file_path, sheet_name='Sheet1')

# Convert 'Date' to datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Get unique IDs
unique_ids = data['ID'].unique()

# Create output directory if not exists
output_dir = "individual_plots"
os.makedirs(output_dir, exist_ok=True)

# Generate individual plots
for id in unique_ids:
    # Filter data for the current ID
    id_data = data[data['ID'] == id]

    # Create a figure
    plt.figure(figsize=(10, 5))

    # Plot predicted probability
    plt.plot(id_data['Date'], id_data['Predicted Probability'], label='Predicted Probability', color='blue')

    # Plot actual target
    plt.plot(id_data['Date'], id_data['Target'], label='Actual Target', color='red', marker='o')

    # Customize plot
    plt.title(f'Predicted vs Actual for ID {id}')
    plt.xlabel('Date')
    plt.ylabel('Probability / Target')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)

    # Save the figure
    output_file = os.path.join(output_dir, f"Predicted_vs_Actual_ID_{id}.png")
    plt.tight_layout()
    plt.savefig(output_file, dpi=300, bbox_inches='tight')
    plt.close()  # Close the figure to save memory

    print(f"Saved: {output_file}")
# Out:
# Saved: individual_plots\Predicted_vs_Actual_ID_6.png
# Saved: individual_plots\Predicted_vs_Actual_ID_9.png
# Saved: individual_plots\Predicted_vs_Actual_ID_13.png
# Saved: individual_plots\Predicted_vs_Actual_ID_15.png
# Saved: individual_plots\Predicted_vs_Actual_ID_19.png
# Saved: individual_plots\Predicted_vs_Actual_ID_22.png
# Saved: individual_plots\Predicted_vs_Actual_ID_26.png
# Saved: individual_plots\Predicted_vs_Actual_ID_30.png

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Load the data from the Excel file
file_path = 'new_test_predictions_with_id.xlsx'
data = pd.read_excel(file_path, sheet_name='Sheet1')

# Convert 'Date' to datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Get unique IDs
unique_ids = data['ID'].unique()

# Create output directory if not exists
output_dir = "individual_plots"
os.makedirs(output_dir, exist_ok=True)

# Define mapping of IDs to region names
id_region_map = {
    6: "Louisiana Coast",
    9: "Louisiana Coast",
    13: "Louisiana Coast",
    15: "Galveston Coast",
    19: "Washington Coast",
    22: "Washington Coast",
    26: "British Columbia",
    30: "France Coast"
}

# Generate individual plots
for id in unique_ids:
    # Filter data for the current ID
    id_data = data[data['ID'] == id]

    # Get region name if available
    region = id_region_map.get(id, "Unknown Region")

    # Create a figure
    plt.figure(figsize=(10, 5))

    # Plot predicted probability
    plt.plot(id_data['Date'], id_data['Predicted Probability'], label='Predicted Probability', color='blue')

    # Plot actual target
    plt.plot(id_data['Date'], id_data['Target'], label='Actual Target', color='red', marker='o')

    # Customize plot title
    title = f"{region}, ID: {id}" if region != "Unknown Region" else f"ID: {id}"
    plt.title(f'Predicted vs Actual - {title}')
    plt.xlabel('Date')
    plt.ylabel('Probability / Target')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)

    # Save the figure
    safe_region = region.replace(" ", "_")
    output_file = os.path.join(output_dir, f"Predicted_vs_Actual_{safe_region}_ID_{id}.png")
    plt.tight_layout()
    plt.savefig(output_file, dpi=300, bbox_inches='tight')
    plt.close()

    print(f"Saved: {output_file}")
# Out:
# Saved: individual_plots\Predicted_vs_Actual_Louisiana_Coast_ID_6.png
# Saved: individual_plots\Predicted_vs_Actual_Louisiana_Coast_ID_9.png
# Saved: individual_plots\Predicted_vs_Actual_Louisiana_Coast_ID_13.png
# Saved: individual_plots\Predicted_vs_Actual_Galveston_Coast_ID_15.png
# Saved: individual_plots\Predicted_vs_Actual_Washington_Coast_ID_19.png
# Saved: individual_plots\Predicted_vs_Actual_Washington_Coast_ID_22.png
# Saved: individual_plots\Predicted_vs_Actual_British_Columbia_ID_26.png
# Saved: individual_plots\Predicted_vs_Actual_France_Coast_ID_30.png

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Load the data from the Excel file
file_path = 'new_test_predictions_with_id.xlsx'
data = pd.read_excel(file_path, sheet_name='Sheet1')

# Convert 'Date' to datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Get unique IDs
unique_ids = data['ID'].unique()

# Create output directory if not exists
output_dir = "individual_plots1"
os.makedirs(output_dir, exist_ok=True)

# Define mapping of IDs to region names
id_region_map = {
    6: "Louisiana Coast",
    9: "Louisiana Coast",
    13: "Louisiana Coast",
    15: "Galveston Coast",
    19: "Washington Coast",
    22: "Washington Coast",
    26: "British Columbia",
    30: "France Coast"
}

# Generate individual plots
for id in unique_ids:
    # Filter data for the current ID
    id_data = data[data['ID'] == id]

    # Get region name if available
    region = id_region_map.get(id, "Unknown Region")

    # Create a figure
    plt.figure(figsize=(10, 5))

    # Plot predicted probability
    plt.plot(id_data['Date'], id_data['Predicted Probability'], label='Predicted Probability', color='blue')

    # Plot actual target
    plt.plot(id_data['Date'], id_data['Target'], label='Actual Target', color='red', marker='o')

    # Add outbreak threshold line at 0.6
    plt.axhline(y=0.6, color='green', linestyle='--', linewidth=1, label='Outbreak Threshold (0.6)')

    # Customize plot title
    title = f"{region}, ID: {id}" if region != "Unknown Region" else f"ID: {id}"
    plt.title(f'Predicted vs Actual - {title}')
    plt.xlabel('Date')
    plt.ylabel('Probability / Target')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)

    # Save the figure
    safe_region = region.replace(" ", "_")
    output_file = os.path.join(output_dir, f"Predicted_vs_Actual_{safe_region}_ID_{id}.png")
    plt.tight_layout()
    plt.savefig(output_file, dpi=300, bbox_inches='tight')
    plt.close()

    print(f"Saved: {output_file}")
# Out:
# Saved: individual_plots1\Predicted_vs_Actual_Louisiana_Coast_ID_6.png
# Saved: individual_plots1\Predicted_vs_Actual_Louisiana_Coast_ID_9.png
# Saved: individual_plots1\Predicted_vs_Actual_Louisiana_Coast_ID_13.png
# Saved: individual_plots1\Predicted_vs_Actual_Galveston_Coast_ID_15.png
# Saved: individual_plots1\Predicted_vs_Actual_Washington_Coast_ID_19.png
# Saved: individual_plots1\Predicted_vs_Actual_Washington_Coast_ID_22.png
# Saved: individual_plots1\Predicted_vs_Actual_British_Columbia_ID_26.png
# Saved: individual_plots1\Predicted_vs_Actual_France_Coast_ID_30.png
